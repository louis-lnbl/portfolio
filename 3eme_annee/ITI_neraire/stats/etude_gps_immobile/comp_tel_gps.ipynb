# %%
import pandas as pd
import numpy as np
from converter_gpx import convert_gpx_to_csv
import matplotlib.pyplot as plt

# %%
convert_gpx_to_csv("20250311-174608 - Immobile 1.gpx", "data_immobile_1.csv")
convert_gpx_to_csv("20250311-175125 - Immobile 2.gpx", "data_immobile_2.csv")
convert_gpx_to_csv("20250311-175248 - Immobile 3.gpx", "data_immobile_3.csv")
# Out:
# Conversion terminée ! Fichier enregistré : data_immobile_1.csv
# Conversion terminée ! Fichier enregistré : data_immobile_2.csv
# Conversion terminée ! Fichier enregistré : data_immobile_3.csv

# %%
data_tel_immobile_1 = pd.read_csv("data_immobile_1.csv")
data_gps_immobile_1 = pd.read_csv("acquisitions_exterieur_statique_gps.csv")
data_tel_immobile_2 = pd.read_csv("data_immobile_2.csv")
data_gps_immobile_2 = pd.read_csv("acquisitions_exterieur_statique2_gps.csv")
data_tel_immobile_3 = pd.read_csv("data_immobile_3.csv")
data_gps_immobile_3 = pd.read_csv("acquisitions_exterieur_statique3_gps.csv")

# %%
print(data_tel_immobile_1)
print(data_gps_immobile_1)
# Out:
#                          UTC   Latitude  Longitude
# 0   2025-03-11T16:46:08.455Z  49.385407   1.068523
# 1       2025-03-11T16:48:27Z  49.385420   1.068555
# 2       2025-03-11T16:48:28Z  49.385420   1.068555
# 3       2025-03-11T16:48:29Z  49.385420   1.068555
# 4       2025-03-11T16:48:30Z  49.385420   1.068555
# 5       2025-03-11T16:48:31Z  49.385420   1.068555
# 6       2025-03-11T16:48:32Z  49.385420   1.068555
# 7       2025-03-11T16:48:33Z  49.385420   1.068555
# 8       2025-03-11T16:48:34Z  49.385420   1.068555
# 9       2025-03-11T16:48:35Z  49.385420   1.068555
# 10      2025-03-11T16:48:36Z  49.385420   1.068555
# 11      2025-03-11T16:48:37Z  49.385420   1.068555
# 12      2025-03-11T16:48:38Z  49.385420   1.068555
# 13      2025-03-11T16:48:39Z  49.385420   1.068555
# 14      2025-03-11T16:48:40Z  49.385420   1.068555
# 15      2025-03-11T16:48:41Z  49.385420   1.068555
# 16      2025-03-11T16:48:42Z  49.385420   1.068555
# ...

# %%
print("Moyenne des latitudes")
print(data_tel_immobile_1.Latitude.mean())
print(data_gps_immobile_1.Latitude.mean())
# Out:
# Moyenne des latitudes
# 49.38541971638299
# 49.385409900793654

# %%
print("Moyenne des longitudes")
print(data_tel_immobile_1.Longitude.mean())
print(data_gps_immobile_1.Longitude.mean())
# Out:
# Moyenne des longitudes
# 1.0685543261702133
# 1.0685732658730158

# %%
print("Variance des latitudes")
print(data_tel_immobile_1.Latitude.var())
print(data_gps_immobile_1.Latitude.var())
# Out:
# Variance des latitudes
# 3.780614894517733e-12
# 7.372080283214746e-13

# %%
print("Variance des longitudes")
print(data_tel_immobile_1.Longitude.var())
print(data_gps_immobile_1.Longitude.var())
# Out:
# Variance des longitudes
# 2.1340189361455668e-11
# 1.8401890568220634e-12

# %%
plt.scatter(data_gps_immobile_1.Latitude, data_gps_immobile_1.Longitude)
plt.scatter(data_tel_immobile_1.Latitude, data_tel_immobile_1.Longitude)

# %%
plt.scatter(data_gps_immobile_2.Latitude, data_gps_immobile_2.Longitude)
plt.scatter(data_tel_immobile_2.Latitude, data_tel_immobile_2.Longitude)

# %%
plt.scatter(data_gps_immobile_3.Latitude, data_gps_immobile_3.Longitude)
plt.scatter(data_tel_immobile_3.Latitude, data_tel_immobile_3.Longitude)
